# %% [markdown]
# ## Ques 1

# %%
import datetime
# Add current date
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Read current date
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 10-04-2023

# %% [markdown]
# ## Ques 2

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 10-04-2023

# %% [markdown]
# ## Ques 3

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-04-10 00:00:00

# %% [markdown]
# ## Ques 4

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# 11785.jpg
# 1DX30275.JPG
# 21st Jan FSDSbootcamp(deep-learning-main) (1).zip
# 21st Jan FSDSbootcamp(deep-learning-main).zip
# 22nd Jan FSDSbootcamp(deep-learning-main).zip
# 23032100570133PUNB_ChallanReceipt (1).pdf
# 23032100570133PUNB_ChallanReceipt (2).pdf
# 23032100570133PUNB_ChallanReceipt.pdf
# 5th Feb FSDSbootcamp(VggNEt-20230205T142235Z-001) (1).zip
# 5th Feb FSDSbootcamp(VggNEt-20230205T142235Z-001).zip
# Agam Resume (2).pdf
# Agam.JPG
# agam.pem
# Anaconda3-2023.03-Windows-x86_64.exe
# ann_image_classifier.ipynb
# ann_image_classifier.py
# aps_data.csv
# Assignment 13
# BatteryCat_v16_portable.zip
# book.db
# books.csv
# books.db
# BraveBrowserSetup.exe
# car jpeg
# car jpeg.webp
# car.jpeg
# cat.jpg
# catdog_accessKeys.csv
# catdog_accessKeys1.csv
# Check your warranty or service status.pdf
# cnn_foundation.ipynb
# cnn_foundation.py
# desktop.ini
# Fraud Transaction Detection.pdf
# Git-2.40.0-64-bit.exe
# GitHubDesktopSetup-x64.exe
# ideaIC-2022.3.3.exe
# ...

# %% [markdown]
# ## Ques 5

# %%
import os 
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '11785.jpg',
#  '1DX30275.JPG',
#  '21st Jan FSDSbootcamp(deep-learning-main) (1).zip',
#  '21st Jan FSDSbootcamp(deep-learning-main).zip',
#  '22nd Jan FSDSbootcamp(deep-learning-main).zip',
#  '23032100570133PUNB_ChallanReceipt (1).pdf',
#  '23032100570133PUNB_ChallanReceipt (2).pdf',
#  '23032100570133PUNB_ChallanReceipt.pdf',
#  '5th Feb FSDSbootcamp(VggNEt-20230205T142235Z-001)',
#  '5th Feb FSDSbootcamp(VggNEt-20230205T142235Z-001) (1).zip',
#  '5th Feb FSDSbootcamp(VggNEt-20230205T142235Z-001).zip',
#  'Agam Resume (2).pdf',
#  'Agam.JPG',
#  'agam.pem',
#  'Anaconda3-2023.03-Windows-x86_64.exe',
#  'ann_image_classifier.ipynb',
#  'ann_image_classifier.py',
#  'aps_data.csv',
#  'Assignment 13',
#  'BatteryCat_v16_portable.zip',
#  'book.db',
#  'books.csv',
#  'books.db',
#  'BraveBrowserSetup.exe',
#  'car jpeg',
#  'car jpeg.webp',
#  'car.jpeg',
#  'cat.jpg',
#  'catdog_accessKeys.csv',
#  'catdog_accessKeys1.csv',
# ...

# %% [markdown]
# ## Ques 6

# %%
import multiprocessing
import time 
import random
import datetime

def process1():
    print(f'Process_1_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Process_1_Endtime -> {datetime.datetime.now()}')
    
def process2():
    print(f'Process_2_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Process_2_Endtime -> {datetime.datetime.now()}')

def process3():
    print(f'Process_3_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Process_3_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=process1)
    p2 = multiprocessing.Process(target=process2)
    p3 = multiprocessing.Process(target=process3)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [raw]
# Process_1_Starttime -> 2023-04-10 12:41:47.658182
# Process_2_Starttime -> 2023-04-10 12:41:47.659773
# Process_3_Starttime -> 2023-04-10 12:41:47.661123
# Process_3_Endtime -> 2023-04-10 12:41:48.661461
# Process_1_Endtime -> 2023-04-10 12:41:49.658550
# Process_2_Endtime -> 2023-04-10 12:41:52.671198

# %% [markdown]
# ## Ques 7

# %%
from datetime import datetime
my_dob = datetime.strptime('04/01/2001','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 2001-01-04 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# ## Ques 8

# %%
from datetime import datetime
my_dob = datetime(2001,1,4)
my_dob.strftime("%A")
# Out:
# 'Thursday'
